# %% [markdown]
# # 지도시각화
#
# ## #01. 필요한 모듈 참조
#
# > pip install --upgrade folium

# %%
import folium

# %% [markdown]
# ## #02. 지도 표현하기
#
# 1) 지도 객체 생성

# %%
# zoom_start : 배율 1~22
map_osm = folium.Map(location =[43.7696674,-79.4159717], zoom_start=17)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 2) 지도객체에 마커 추가
#
# 일반마커

# %%
marker1 = folium.Marker([43.7696674,-79.4159717], popup='Gibson', icon=folium.Icon(color='red', icon='info-sign'))
marker1.add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 구름아이콘

# %%
marker2 = folium.Marker([43.7696674,-79.4159717], popup='Gibson', icon=folium.Icon(color='blue', icon='cloud'))
marker2.add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 원형마커(범위지정)

# %%
marker3 = folium.CircleMarker([43.7696674,-79.4159717], radius = 300, color ='#3186cc', fill_color='#3186cc', popup='Gibson')
marker3.add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3) 파일로 저장하기

# %%
map_osm.save('c:/WorkSpace/Pandas/map1.html') #파일이 저장될 위치
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-e0710ba05c3f> in <module>
# ----> 1 map_osm.save('c:/WorkSpace/Pandas/map1.html') #파일이 저장될 위치
#
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\branca\element.py in save(self, outfile, close_file, **kwargs)
#     162         """
#     163         if isinstance(outfile, text_type) or isinstance(outfile, binary_type):
# --> 164             fid = open(outfile, 'wb')
#     165         else:
#     166             fid = outfile
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:/WorkSpace/Pandas/map1.html'

# %% [markdown]
# ## #03. 다른 형태의 지도

# %%
# zoom_start : 배율 1~22
map_osm = folium.Map(location =[43.7696674,-79.4159717], zoom_start=17, titles ='StamenToner')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# zoom_start : 배율 1~22
map_osm = folium.Map(location =[43.7696674,-79.4159717], zoom_start=10, titles ='StamenTerrain')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

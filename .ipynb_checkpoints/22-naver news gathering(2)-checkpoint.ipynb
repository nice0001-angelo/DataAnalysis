# %% [markdown]
# 네이버 뉴스 수집(2)
#
# 컨텐츠로 접근할 수 있는 웹 페이지의 주소들을 수집하고 그 목록을 리스트로 정의.
#
# 리스트에 대해 반복문을 수행하면서 컨텐츠 수집
#
# ## 01. 필요한 모듈 참조

# %%
import requests  # -> 웹페이지 요청 모듈
import os       # -> 날짜 처리 모듈
import datetime as dt # ->날짜 처리 모듈
from bs4 import BeautifulSoup # -> 웹페이지 소스코드 분석 모듈
from pandas import DataFrame

# %% [markdown]
# -----------------------------------------
# ## #02. 수집 준비
#
# ### 1)접속을 수행하기 위한 session 객체 생성

# %%
# 접속 세션 만들기
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36"

session = requests.Session()
session.headers.update({'User-agent':user_agent, 'referer':None})

# %% [markdown]
# ### 2)접근할 페이지 주소(네이버 메인 뉴스)

# %%
content_url = "https://news.naver.com"

# %% [markdown]
# ### 3)수집된 기사들이 텍스트로 저장될 폴더 생성

# %%
# 뉴스 기사가 저장될 폴더이름 구성
datetime = dt.datetime.now().strftime("%y%m%d_%H%M%S")
dirname = "%s_%s" % ('뉴스기사', datetime)

# 뉴스기사를 텍스트 파일로 저장할 폴더 만들기
if not os.path.exists(dirname):
    os.mkdir(dirname)

# %% [markdown]
# ## #03.컨텐츠의 주소들을 수집하기
#
# 1) 네이버 뉴스 메인 소스코드 가져오기

# %%
r = session.get(content_url)

#-> 결과확인
if r.status_code != 200:
    print("%d 에러가 발생했습니다." % r.status_code)
    # 즉시 종료 --> jupyter가 재시작됨
    quit()
    
r.encoding = "euc-kr"
r.text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\t\n\t\t\n\t\n\t\n\n\n<!DOCTYPE HTML>\n<html lang="ko">\n<head>\n<meta charset="euc-kr">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="referrer" contents="always">\n<meta http-equiv="refresh" content="600" />\n<meta name="viewport" content="width=1106" />\n\r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n\r\n<meta property="og:title"       content="네이버 뉴스">\r\n<meta property="og:type"        content="website">\r\n<meta property="og:url"         content="http://news.naver.com/main/home.nhn">\r\n<meta property="og:image"       content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png"/>\r\n<meta property="og:description" content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공">\r\n<meta property="og:article:author"\tcontent="네이버"/>\r\n\r\n<meta name="twitter:card"\t\tcontent="summary">\r\n<meta name="twitter:title"\t\tcontent="네이버 뉴스">\r\n<meta name="twitter:site"       content="네이버 뉴스">\r\n<meta name="twitter:creator"    content="네이버 뉴스">\r\n<meta name="twitter:image"\t\tcontent="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png">\r\n<meta name="twitter:description" content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공">\r\n\n<title>네이버 뉴스</title>\n<link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" />\r\n\r\n\r\n\r\n\t\r\n\t\r\n\t\r\n\n\n\t\n\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20191030_165315/css/common.css"/>\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20191030_165315/css/news.css"/>\n\t\t\n\t\t\n\t\n\t\n\n\n\r\n\r\n\r\n\r\n<script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20191030_165315/js/news.jindo.js" charset="euc-kr"></script>\r\n\r\n\r\n\n\n<script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20191030_165315/js/news.jquery.js" charset="utf-8"></script>\n\n\n\n\n\n\t\n\t\t\n\t\t\n\t\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\t\n\t\n\t\n\n\n\n\n\n\n<script type="text/javascript">\ndocument.domain=\'naver.com\';\nvar _MAIN_NEWS_MENU_ID=\'home\';\nvar _MAIN_NEWS_SECTION_ID=\'100\';\nvar ccsrv=\'cc.naver.com\';\nvar g_ssc=\'news.home\';\nwindow.nsc = g_ssc; \nvar gnb_service=\'news\';\nvar gnb_logout=encodeURIComponent(location.href);\nvar gnb_template=\'gnb_utf8\';\nvar gnb_brightness = 1;\nvar gnb_one_naver = 1;\nvar gnb_searchbox=\'on\';\nvar gnb_shortnick=\'on\';\n\nvar gnb_timestamp = "Sat Nov 02 13:08:42 KST 2019";\n</script>\n\n\n\n\n<script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20191030_165315/js/news.service.js" charset="euc-kr"></script>\n\n\n\n\n\n</head>\n\n<body class="chrome">\n\t<div id="wrap">\n\t\t\n\t\t<div id="da_base"></div>\n\t\t<div id="da_stake"></div>\n\t\t\r\n\r\n\r\n<div id="header" class="header">\r\n\t\r\n\t<div id="u_skip">\r\n\t\t<a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>\r\n\t\t<a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>\r\n\t</div>\r\n\t\r\n\r\n\t<div class="snb_area">\r\n\t\t<div class="snb_inner">\r\n\t\t\t<div class="gnb_wrap">\r\n   <!-- GNB 마크업 -->\r\n   <div id="gnb"></div>\r\n   <!-- //GNB 마크업 -->\r\n</div>\r\n\t\t\t\r\n\r\n\r\n<div id="snb_wrap">\r\n    <h1>\r\n        <a href="https://www.naver.com/" class="h_logo nclicks(STA.naver)"><span class="blind">NAVER</span></a>\r\n        <a href="/" class="h_news nclicks(STA.news)"><span class="blind">뉴스</span></a>\r\n    </h1>\r\n    <ul class="snb_related_service">\r\n        <li><span class="snb_bdr"></span><a href="https://entertain.naver.com/home" class="nclicks(STA.enter)"><img src="https://imgnews.pstatic.net/image/news/ ...

# %% [markdown]
# 2) 컨텐츠의 URL 수집

# %%
# 웹 페이지의 소스코드 HTML 분석 객체로 생성
soup = BeautifulSoup(r.text, 'html.parser')

# CSS 선택자를 활용하여 가져오기를 원하는 부분 지정
# -> 여러개의 선택자를 사용해야 할 경우 콤마(,)로 구분
selector = soup.select('.lnk_hdline_main_article, .lnk_hdline_article, .mtype_img > dt > a, .mlist2 > li > a')

if not selector:  #가져온 내용이 없다면?
    print("뉴스기사 크롤링 실패")
    quit()

selector
# Out:
# [<a class="lnk_hdline_main_article nclicks('mai.image', '880000D8_000000000000000011185281', 'airsGParam', '0', 'news_qm_v2.0', 'VDO9t2JH4urF06tR')" href="/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=001&amp;aid=0011185281">
#  <img alt="'독도 추락헬기' 수중수색 집중…무인잠수정, 실종자 수습 시도(종합)" height="190" src="https://imgnews.pstatic.net/image/001/2019/11/02/PYH2019110117230001300_P2_20191102121005378.jpg?type=nf270_166" width="300"/>
#  <div class="hdline_flick_mask">
#  <p class="hdline_flick_tit">'독도 추락헬기' 수중수색 집중…무인잠수정, 실…</p>
#  </div>
#  </a>,
#  <a class="lnk_hdline_main_article nclicks('mai.image', '880000D8_000000000000000011185298', 'airsGParam', '0', 'news_qm_v2.0', 'VDO9t2JH4urF06tR')" href="/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=001&amp;aid=0011185298">
#  <img alt='미국·독일 미사일 전문가 "北 초대형 방사포 완성도 의문"' height="190" src="https://imgnews.pstatic.net/image/001/2019/11/02/AKR20191102028600504_01_i_20191102121359979.jpg?type=nf270_166" width="300"/>
#  <div class="hdline_flick_mask">
#  <p class="hdline_flick_tit">미국·독일 미사일 전문가 "北 초대형 방사포 완…</p>
#  </div>
#  </a>,
#  <a class="lnk_hdline_article nclicks('mai.text1', '880000D8_000000000000000011185268', 'airsGParam', '0', 'news_qm_v2.0', 'VDO9t2JH4urF06tR')" href="/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=001&amp;aid=0011185268">
#                                          강창일 "日정부, 언론플레이 하지 말고 협상 테이블 나와야"
#                                      </a>,
#  <a class="lnk_hdline_article nclicks('mai.text1', '880000F2_000000000000000002949757', 'airsGParam', '0', 'news_qm_v2.0', 'VDO9t2JH4urF06tR')" href="/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0002949757">
#                                          한국당→정의당 간 이자스민···금태섭 "여당이 놓쳐 아쉽다"
#                                      </a>,
#  <a class="lnk_hdline_article nclicks('mai.text1', '88000385_000000000000000004565067', 'airsGParam', '0', 'news_qm_v2.0', 'VDO9t2JH4urF06tR')" href="/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=277&amp;aid=0004565067">
#                                          '네탓' 공방으로 번진 '타다' 기소 논란
#                                      </a>,
#  <a class="lnk_hdline_article nclicks('mai.text1', '880000D8_000000000000000011185275', 'airsGParam', '0', 'news_qm_v2.0', 'VDO9t2JH4urF06tR')" href="/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=001&amp;aid=0011185275">
#                                          경찰, 이춘재 살해 '화성 실종 초등생' 유골 수색 재개
#                                      </a>,
#  <a class="lnk_hdline_article nclicks('mai.text1', '88000108_000000000000000003644804', 'airsGParam', '0', 'news_qm_v2.0', 'VDO9t2JH4urF06tR')" href="/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=011&amp;aid=0003644804">
#                                           MB보다 조국 동생을 더 고민한 영장판사들[서초동 야단법석]
#                                      </a>,
#  <a class="nclicks('hom.airscont','880000CE_000000000000000000954398', 'airsGParam', '0', 'news_sec_v2.0', 'X0jU5KH9UGJA0Sss')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=082&amp;aid=0000954398">
#  <img alt='홍준표 "계속된 헛발질 답답…색소폰은 총선 이기고 맘껏 불어라"' height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/082/2019/11/02/954398.jpg?type=nf220_140" width="220"/>
#  <span class="trans_border"></span>
#  </a>,
#  <a class="nclicks('hom.airscont','880000CE_000000000000000000954398', 'airsGParam', '0', 'news_sec_v2.0', 'X0jU5KH9UGJA0Sss')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=005&amp;aid=0001255173">
#  <strong>강기정 웃음 터지게 한 ‘김재정·노영민 설전’ 상황 살펴보니</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','880000CE_000000000000000000954398', 'airsGParam', '0', 'news_sec_v2.0', 'X0jU5KH9UGJA0Sss')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=057&amp;aid=0001392994">
#  <strong>[단독] 카터, 친서보내 전두환에 경고…"보통선거하고 DJ 놔둬라"</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','880000CE_000000000000000000954398', 'airsGParam', '0', 'news_sec_v2.0', 'X0jU5KH9UGJA0Sss')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=006&amp;aid=0000099509">
#  <strong>"최저임금 올려 '쪼개기 알바' 늘었다? 한국당 주장 가짜"</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','880000CE_000000000000000000954398', 'airsGParam', '0', 'news_sec_v2.0', 'X0jU5KH9UGJA0Sss')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0009537668">
#  <strong>與금태섭 "정의당 간 이자스민 응원…영입 생각못해 안타까워"</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','880000CE_000000000000000000954398', 'airsGParam', '0', 'news_sec_v2.0', 'X0jU5KH9UGJA0Sss')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0002949757">
#  <strong>한국당→정의당 간 이자스민···금태섭 "여당이 놓쳐 아쉽다"</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','88000108_000000000000000003644803', 'airsGParam', '0', 'news_sec_v2.0', 'O0gAN0fUZpIZMLft')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=011&amp;aid=0003644803">
#  <img alt="P2P 세계최초 법제화...중·저신용자 대출금리 낮아질까" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/011/2019/11/02/3644803.jpg?type=nf220_140" width="220"/>
#  <span class="trans_border"></span>
#  </a>,
#  <a class="nclicks('hom.airscont','88000108_000000000000000003644803', 'airsGParam', '0', 'news_sec_v2.0', 'O0gAN0fUZpIZMLft')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=011&amp;aid=0003644800">
#  <strong>[뒷북경제] '비정규직 87만 증가' 아니라고? 병행조사 논란에 통계 신뢰도 ↓</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','88000108_000000000000000003644803', 'airsGParam', '0', 'news_sec_v2.0', 'O0gAN0fUZpIZMLft')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=421&amp;aid=0004283446">
#  <strong>틱톡 제2의 화웨이 되나…미국 틱톡 집중공격 나서</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','88000108_000000000000000003644803', 'airsGParam', '0', 'news_sec_v2.0', 'O0gAN0fUZpIZMLft')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=018&amp;aid=0004507000">
#  <strong>[집Talk]지방미분양 심각하다는데…세금 깎아줘야 해?</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','88000108_000000000000000003644803', 'airsGParam', '0', 'news_sec_v2.0', 'O0gAN0fUZpIZMLft')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=011&amp;aid=0003644798">
#  <strong>화웨이 제재에···희비 갈린 하이닉스·삼성</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','88000108_000000000000000003644803', 'airsGParam', '0', 'news_sec_v2.0', 'O0gAN0fUZpIZMLft')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=032&amp;aid=0002972389">
#  <strong>"배달원 혐오, 플랫폼 노동자의 죽음을 부른다"</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','08138262_000000000000000000399408', 'airsGParam', '0', 'news_sec_v2.0', 'uCky1mF6UEr8fDFW')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=422&amp;aid=0000399408">
#  <img alt="[토요와이드] 헬기 동체·실종자 추정 시신 1구 발견" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/422/2019/11/02/399408.jpg?type=nf220_140" width="220"/>
#  <strong class="r_ico r_vod_large">동영상 기사</strong>
#  <span class="trans_border"></span>
#  </a>,
#  <a class="nclicks('hom.airscont','08138262_000000000000000000399408', 'airsGParam', '0', 'news_sec_v2.0', 'uCky1mF6UEr8fDFW')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=277&amp;aid=0004565074">
#  <strong>김태호 서울교통공사 사장 최대 위기...채용 비리혐의 검찰 고발</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','08138262_000000000000000000399408', 'airsGParam', '0', 'news_sec_v2.0', 'uCky1mF6UEr8fDFW')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=001&amp;aid=0011185295">
#  <strong>경북소방 헬기 2대 모두 야간에는 운용 불가</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','08138262_000000000000000000399408', 'airsGParam', '0', 'news_sec_v2.0', 'uCky1mF6UEr8fDFW')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=022&amp;aid=0003410962">
#  <strong>아내부터 조카까지 줄줄이 구속… 조국 턱밑 향하는 檢 칼끝</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','08138262_000000000000000000399408', 'airsGParam', '0', 'news_sec_v2.0', 'uCky1mF6UEr8fDFW')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=056&amp;aid=0010759643">
#  <strong>[똑똑팩톡] 유튜브 ‘노란딱지’는 정권의 보수 탄압??</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','08138262_000000000000000000399408', 'airsGParam', '0', 'news_sec_v2.0', 'uCky1mF6UEr8fDFW')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=022&amp;aid=0003410961">
#  <strong>평점 테러 시달렸던 '82년생 김지영' 200만 관객 돌파…페미니즘 논란 여전? [일상톡톡 플러스]</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','88000101_000000000000000002109322', 'airsGParam', '0', 'news_sec_v2.0', 'OYI1DX0PJyWMgGH8')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=002&amp;aid=0002109322">
#  <img alt="사회주의자의 친동생 박정희, '두고 보자'" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/002/2019/11/02/2109322.jpg?type=nf220_140" width="220"/>
#  <span class="trans_border"></span>
#  </a>,
#  <a class="nclicks('hom.airscont','88000101_000000000000000002109322', 'airsGParam', '0', 'news_sec_v2.0', 'OYI1DX0PJyWMgGH8')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=047&amp;aid=0002245401">
#  <strong>"그러니까 조커가 잘했단 거야"란 물음에 대한 답</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','88000101_000000000000000002109322', 'airsGParam', '0', 'news_sec_v2.0', 'OYI1DX0PJyWMgGH8')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=047&amp;aid=0002245400">
#  <strong>수만 개의 조명이 반짝... 청도의 밤은 낮보다 아름답다</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','88000101_000000000000000002109322', 'airsGParam', '0', 'news_sec_v2.0', 'OYI1DX0PJyWMgGH8')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=296&amp;aid=0000043158">
#  <strong>먹는 시간, 음식만큼 건강에 큰 영향(연구)</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','88000101_000000000000000002109322', 'airsGParam', '0', 'news_sec_v2.0', 'OYI1DX0PJyWMgGH8')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=037&amp;aid=0000027074">
#  <strong>[이슈] 전자담배, 그때는 괜찮고 지금은 해롭다?</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','88000101_000000000000000002109322', 'airsGParam', '0', 'news_sec_v2.0', 'OYI1DX0PJyWMgGH8')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=018&amp;aid=0004507007">
#  <strong>[임현영의 車한잔]“리콜 관련없다”지만..잇따른 화재에 주춤하는 BMW</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','08138262_000000000000000000399407', 'airsGParam', '0', 'news_sec_v2.0', 't2L0DBf9q2CCju7Q')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=422&amp;aid=0000399407">
#  <img alt="트럼프 &quot;우크라 녹취록 낭독&quot;…탄핵공식화 '맞불'" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/422/2019/11/02/399407.jpg?type=nf220_140" width="220"/>
#  <strong class="r_ico r_vod_large">동영상 기사</strong>
#  <span class="trans_border"></span>
#  </a>,
#  <a class="nclicks('hom.airscont','08138262_000000000000000000399407', 'airsGParam', '0', 'news_sec_v2.0', 't2L0DBf9q2CCju7Q')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=001&amp;aid=0011185298">
#  <strong>미국·독일 미사일 전문가 "北 초대형 방사포 완성도 의문"</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','08138262_000000000000000000399407', 'airsGParam', '0', 'news_sec_v2.0', 't2L0DBf9q2CCju7Q')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=003&amp;aid=0009537679">
#  <strong>트럼프 대통령 "미중 1단계 무역합의 아이오와서 체결 검토"</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','08138262_000000000000000000399407', 'airsGParam', '0', 'news_sec_v2.0', 't2L0DBf9q2CCju7Q')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=001&amp;aid=0011185291">
#  <strong>또 '가스실' 된 뉴델리…공사 중단·휴교령·마스크 대량 배포</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','08138262_000000000000000000399407', 'airsGParam', '0', 'news_sec_v2.0', 't2L0DBf9q2CCju7Q')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=469&amp;aid=0000436506">
#  <strong>‘제2의 오바마’ 주목받던 美 민주당 신성 오로크 대선 경선 포기</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','08138262_000000000000000000399407', 'airsGParam', '0', 'news_sec_v2.0', 't2L0DBf9q2CCju7Q')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=001&amp;aid=0011185290">
#  <strong>벌써 5번째 국토안보장관…트럼프, 차관대행을 장관대행에 발탁</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','8800011E_000000000000000002173901', 'airsGParam', '0', 'news_sec_v2.0', '8QUBfKbWKkjYcART')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=105&amp;oid=092&amp;aid=0002173901">
#  <img alt="구글, 핏빗 인수…'웨어러블 날개' 달았다" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/092/2019/11/02/2173901.jpg?type=nf220_140" width="220"/>
#  <span class="trans_border"></span>
#  </a>,
#  <a class="nclicks('hom.airscont','8800011E_000000000000000002173901', 'airsGParam', '0', 'news_sec_v2.0', '8QUBfKbWKkjYcART')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=105&amp;oid=009&amp;aid=0004456256">
#  <strong>[블리즈컨2019] 알렌 브랙 사장, 하스스톤 게이머 징계 “성급했다”</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','8800011E_000000000000000002173901', 'airsGParam', '0', 'news_sec_v2.0', '8QUBfKbWKkjYcART')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=105&amp;oid=014&amp;aid=0004320499">
#  <strong>웨어러블 기기, 내년 폭풍 성장..삼성-애플 각축</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','8800011E_000000000000000002173901', 'airsGParam', '0', 'news_sec_v2.0', '8QUBfKbWKkjYcART')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=105&amp;oid=277&amp;aid=0004565054">
#  <strong>네이버VS카카오 '금융공룡'으로 진화하는 IT공룡들</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','8800011E_000000000000000002173901', 'airsGParam', '0', 'news_sec_v2.0', '8QUBfKbWKkjYcART')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=105&amp;oid=366&amp;aid=0000446613">
#  <strong>[중국 IT 열전] 현대차⋅도요타 러브콜 받은 中 자율주행 유니콘 포니닷에이아이</strong>
#  </a>,
#  <a class="nclicks('hom.airscont','8800011E_000000000000000002173901', 'airsGParam', '0', 'news_sec_v2.0', '8QUBfKbWKkjYcART')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=105&amp;oid=001&amp;aid=0011185231">
#  <strong>기후변화로 토양내 비소 늘며 쌀 생산량 대폭 줄어 식량위기</strong>
#  </a>]

# %% [markdown]
# 3) 수집한 <a> 태그에서 URL만 추출

# %%
# 뉴스기사의 본문 URL을 저장할 리스트
url_list = []

#리스트의 원소들에 대한 반복 처리
for item in selector:
    #print(type(item.attrs))
    #print(item.attrs)
    
    #각 원소(링크)에 속성들(attrs) 중에 href 속성이 있다면 그 값을 별도로 준비한 리스트에 추기
    if "href" in item.attrs:
        if content_url in item['href']:
            url_list.append(item['href'])
        else:
            url_list.append(content_url + item['href'])

url_list
# Out:
# ['https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011185281',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011185298',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011185268',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=025&aid=0002949757',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=277&aid=0004565067',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011185275',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=011&aid=0003644804',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=082&aid=0000954398',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=005&aid=0001255173',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=057&aid=0001392994',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=006&aid=0000099509',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=003&aid=0009537668',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=025&aid=0002949757',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=011&aid=0003644803',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=011&aid=0003644800',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=421&aid=0004283446',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=018&aid=0004507000',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=011&aid=0003644798',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=032&aid=0002972389',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=422&aid=0000399408',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=277&aid=0004565074',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011185295',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=022&aid=0003410962',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=056&aid=0010759643',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=022&aid=0003410961',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=002&aid=0002109322',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=047&aid=0002245401',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=047&aid=0002245400',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=296&aid=0000043158',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=037&aid=0000027074',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=018&aid=0004507007',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=422&aid=0000399407',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011185298',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=003&aid=0009537679',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011185291',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=469&aid=0000436506',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011185290',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=092&aid=0002173901',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=009&aid=0004456256',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=014&aid=0004320499',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=277&aid=0004565054',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=366&aid=0000446613',
#  'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=001&aid=0011185231']

# %%
## 04.뉴스기사들 수집
# URL 목록만큼 반복
for i, url in enumerate(url_list):
    print("%d번째 뉴스기사 수집중...>> %s" % (i+1, url))
    
    r = session.get(url)
    
    if r.status_code != 200:
        print("%d 에러가 발생했습니다." % r.status_code)
        continue
    
    r.encoding = "euc-kr"
    
    soup = BeautifulSoup(r.text, 'html.parser')
    
    main_content = soup.select("#main_content")
    title = main_content[0].select("#articleTitle")
    title_str = title[0].text.strip()
    # 기사 제목에서 파일이름으로 사용할 수 없는 특수문자 제거
    title_str = title_str.replace("'","")
    title_str = title_str.replace("\"","")
    title_str = title_str.replace("?","")
    title_str = title_str.replace("'","")
    title_str = title_str.replace("'","")
    title_str = title_str.replace("/","")
    title_str = title_str.replace(">","")
    title_str = title_str.replace("<","")

    #본문 가져오기
    article = main_content[0].select('#articleBodyContents')
    article_item = article[0]
    
    for target in article_item.find_all('script'): target.extract()
    for target in article_item.find_all('a'): target.extract()
    for target in article_item.find_all('span'): target.extract()
    for target in article_item.find_all('div'): target.extract()
    for target in article_item.find_all('br'): target.replace_with("\n")
        
    article_str = article_item.text.strip()
    
    # 제목과 내용이 모두 존재한다면?
    if title_str and article_str:
        # 기사 제목을 파일명으로 지정하여 내용을 텍스트로 저장한다.
        fname = dirname + "/" + title_str + ".txt"
        with open(fname, 'w', encoding = "utf-8") as f:
            f.write(article_str)
            print(" >> 파일저장 성공: " + fname)
# Out:
# 1번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011185281
#  >> 파일저장 성공: 뉴스기사_191102_130840/독도 추락헬기 수중수색 집중…무인잠수정, 실종자 수습 시도(종합).txt
# 2번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011185298
#  >> 파일저장 성공: 뉴스기사_191102_130840/미국·독일 미사일 전문가 北 초대형 방사포 완성도 의문.txt
# 3번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011185268
#  >> 파일저장 성공: 뉴스기사_191102_130840/강창일 日정부, 언론플레이 하지 말고 협상 테이블 나와야.txt
# 4번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=025&aid=0002949757
#  >> 파일저장 성공: 뉴스기사_191102_130840/한국당→정의당 간 이자스민···금태섭 여당이 놓쳐 아쉽다.txt
# 5번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=277&aid=0004565067
#  >> 파일저장 성공: 뉴스기사_191102_130840/네탓 공방으로 번진 타다 기소 논란.txt
# 6번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011185275
#  >> 파일저장 성공: 뉴스기사_191102_130840/경찰, 이춘재 살해 화성 실종 초등생 유골 수색 재개.txt
# 7번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=011&aid=0003644804
#  >> 파일저장 성공: 뉴스기사_191102_130840/[서초동 야단법석] MB보다 조국 동생을 더 고민한 영장판사들.txt
# 8번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=082&aid=0000954398
#  >> 파일저장 성공: 뉴스기사_191102_130840/홍준표 계속된 헛발질 답답…색소폰은 총선 이기고 맘껏 불어라.txt
# 9번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=005&aid=0001255173
#  >> 파일저장 성공: 뉴스기사_191102_130840/강기정 웃음 터지게 한 ‘김재정·노영민 설전’ 상황 살펴보니.txt
# 10번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=057&aid=0001392994
#  >> 파일저장 성공: 뉴스기사_191102_130840/[단독] 카터, 친서보내 전두환에 경고…보통선거하고 DJ 놔둬라.txt
# 11번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=006&aid=0000099509
#  >> 파일저장 성공: 뉴스기사_191102_130840/최저임금 올려 쪼개기 알바 늘었다 한국당 주장 가짜.txt
# 12번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=003&aid=0009537668
#  >> 파일저장 성공: 뉴스기사_191102_130840/與금태섭 정의당 간 이자스민 응원…영입 생각못해 안타까워.txt
# 13번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=100&oid=025&aid=0002949757
#  >> 파일저장 성공: 뉴스기사_191102_130840/한국당→정의당 간 이자스민···금태섭 여당이 놓쳐 아쉽다.txt
# 14번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=011&aid=0003644803
#  >> 파일저장 성공: 뉴스기사_191102_130840/P2P 세계최초 법제화...중·저신용자 대출금리 낮아질까.txt
# 15번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=011&aid=0003644800
#  >> 파일저장 성공: 뉴스기사_191102_130840/[뒷북경제] 비정규직 87만 증가 아니라고 병행조사 논란에 통계 신뢰도 ↓.txt
# 16번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=421&aid=0004283446
#  >> 파일저장 성공: 뉴스기사_191102_130840/틱톡 제2의 화웨이 되나…미국 틱톡 집중공격 나서.txt
# 17번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=018&aid=0004507000
#  >> 파일저장 성공: 뉴스기사_191102_130840/[집Talk]지방미분양 심각하다는데…세금 깎아줘야 해.txt
# 18번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=011&aid=0003644798
#  >> 파일저장 성공: 뉴스기사_191102_130840/화웨이 제재에···희비 갈린 하이닉스·삼성.txt
# 19번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=101&oid=032&aid=0002972389
#  >> 파일저장 성공: 뉴스기사_191102_130840/배달원 혐오, 플랫폼 노동자의 죽음을 부른다.txt
# 20번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=422&aid=0000399408
#  >> 파일저장 성공: 뉴스기사_191102_130840/[토요와이드] 헬기 동체·실종자 추정 시신 1구 발견.txt
# 21번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=277&aid=0004565074
#  >> 파일저장 성공: 뉴스기사_191102_130840/김태호 서울교통공사 사장 최대 위기...채용 비리혐의 검찰 고발.txt
# 22번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=001&aid=0011185295
#  >> 파일저장 성공: 뉴스기사_191102_130840/경북소방 헬기 2대 모두 야간에는 운용 불가.txt
# 23번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=022&aid=0003410962
#  >> 파일저장 성공: 뉴스기사_191102_130840/아내부터 조카까지 줄줄이 구속… 조국 턱밑 향하는 檢 칼끝.txt
# 24번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=056&aid=0010759643
#  >> 파일저장 성공: 뉴스기사_191102_130840/[똑똑팩톡] 유튜브 ‘노란딱지’는 정권의 보수 탄압.txt
# 25번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=022&aid=0003410961
#  >> 파일저장 성공: 뉴스기사_191102_130840/평점 테러 시달렸던 82년생 김지영 200만 관객 돌파…페미니즘 논란 여전 [일상톡톡 플러스].txt
# 26번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=002&aid=0002109322
#  >> 파일저장 성공: 뉴스기사_191102_130840/사회주의자의 친동생 박정희, 두고 보자.txt
# 27번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=047&aid=0002245401
#  >> 파일저장 성공: 뉴스기사_191102_130840/그러니까 조커가 잘했단 거야란 물음에 대한 답.txt
# 28번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=047&aid=0002245400
#  >> 파일저장 성공: 뉴스기사_191102_130840/수만 개의 조명이 반짝... 청도의 밤은 낮보다 아름답다.txt
# 29번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=296&aid=0000043158
#  >> 파일저장 성공: 뉴스기사_191102_130840/먹는 시간, 음식만큼 건강에 큰 영향(연구).txt
# 30번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=037&aid=0000027074
#  >> 파일저장 성공: 뉴스기사_191102_130840/[이슈] 전자담배, 그때는 괜찮고 지금은 해롭다.txt
# 31번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=018&aid=0004507007
#  >> 파일저장 성공: 뉴스기사_191102_130840/[임현영의 車한잔]“리콜 관련없다”지만..잇따른 화재에 주춤하는 BMW.txt
# 32번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=422&aid=0000399407
#  >> 파일저장 성공: 뉴스기사_191102_130840/트럼프 우크라 녹취록 낭독…탄핵공식화 맞불.txt
# 33번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011185298
#  >> 파일저장 성공: 뉴스기사_191102_130840/미국·독일 미사일 전문가 北 초대형 방사포 완성도 의문.txt
# 34번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=003&aid=0009537679
#  >> 파일저장 성공: 뉴스기사_191102_130840/트럼프 대통령 미중 1단계 무역합의 아이오와서 체결 검토.txt
# 35번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011185291
#  >> 파일저장 성공: 뉴스기사_191102_130840/또 가스실 된 뉴델리…공사 중단·휴교령·마스크 대량 배포.txt
# 36번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=469&aid=0000436506
#  >> 파일저장 성공: 뉴스기사_191102_130840/‘제2의 오바마’ 주목받던 美 민주당 신성 오로크 대선 경선 포기.txt
# 37번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=104&oid=001&aid=0011185290
#  >> 파일저장 성공: 뉴스기사_191102_130840/벌써 5번째 국토안보장관…트럼프, 차관대행을 장관대행에 발탁.txt
# 38번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=092&aid=0002173901
#  >> 파일저장 성공: 뉴스기사_191102_130840/구글, 핏빗 인수…웨어러블 날개 달았다.txt
# 39번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=009&aid=0004456256
#  >> 파일저장 성공: 뉴스기사_191102_130840/[블리즈컨2019] 알렌 브랙 사장, 하스스톤 게이머 징계 “성급했다”.txt
# 40번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=014&aid=0004320499
#  >> 파일저장 성공: 뉴스기사_191102_130840/웨어러블 기기, 내년 폭풍 성장..삼성-애플 각축.txt
# 41번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=277&aid=0004565054
#  >> 파일저장 성공: 뉴스기사_191102_130840/네이버VS카카오 금융공룡으로 진화하는 IT공룡들.txt
# 42번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=366&aid=0000446613
#  >> 파일저장 성공: 뉴스기사_191102_130840/[중국 IT 열전] 현대차⋅도요타 러브콜 받은 中 자율주행 유니콘 포니닷에이아이.txt
# 43번째 뉴스기사 수집중...>> https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=001&aid=0011185231
#  >> 파일저장 성공: 뉴스기사_191102_130840/기후변화로 토양내 비소 늘며 쌀 생산량 대폭 줄어 식량위기.txt

# %% [markdown]
# ## 01.필요한 모듈 참조
#
# 워드클라우드 모듈 설치
#
# -- pip install --upgrade worldcloud
#
# 한글 형태소 분석 모듈 설치
#
# 1. java 1.8 버전에 대한 개발환경이 필수적으로 필요함 : 자바 환경변수 설정 JAVA_HOME, PATH, 값 설정이 필요함(책, 서핑 참조)
#     --> 명령프롬프트에서 다음으로 확인 가능
#     javac -version
# 2. VC++ 개발환경의 2014년도 버전이 필수적으로 필요함
# 3. 개발환경 완료 후 모듈 설치
#
# JAVA와 파이썬 연동 기능을 제공하는 패키지 설치(버전주의)
# --> pip install --upgrade jpype1==0.6.3
#
# Konlpy 설치
# -- pip install --upgrade konlpy
